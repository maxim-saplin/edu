# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
data = sm. datasets.get_rdataset ('Guerry', 'HistData').data
data.head()
# Out:
#    dept Region    Department  Crime_pers  Crime_prop  Literacy  Donations  \
# 0     1      E           Ain       28870       15890        37       5098
# 1     2      N         Aisne       26226        5521        51       8901
# 2     3      C        Allier       26747        7925        13      10973
# 3     4      E  Basses-Alpes       12935        7289        46       2733
# 4     5      E  Hautes-Alpes       17488        8174        69       6962
#
#    Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 0    33120     35039    2:Med  ...             71           60
# 1    14572     12831    2:Med  ...              4           82
# 2    17044    114121    2:Med  ...             46           42
# 3    23018     14238     1:Sm  ...             70           12
# 4    23076     16171     1:Sm  ...             22           23
#
#    Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# ...

# %%
results = smf.ols( 'Lottery ~ Literacy + np. log (Pop1831) ', data = data).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Lottery   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     22.20
# Date:                Sun, 14 Jan 2024   Prob (F-statistic):           1.90e-08
# Time:                        21:48:32   Log-Likelihood:                -379.82
# No. Observations:                  86   AIC:                             765.6
# Df Residuals:                      83   BIC:                             773.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
import pandas as pd
data = pd.read_csv('datasets/Advertising.csv',index_col = 0)
data.head()
# Out:
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  Sales ($)
# 1             230.1                 37.8                     69.2       22.1
# 2              44.5                 39.3                     45.1       10.4
# 3              17.2                 45.9                     69.3        9.3
# 4             151.5                 41.3                     58.5       18.5
# 5             180.8                 10.8                     58.4       12.9

# %%
model = smf.ols(formula='Q("Sales ($)") ~ Q("TV Ad Budget ($)")', data=data)
model = model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         Q("Sales ($)")   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Sun, 14 Jan 2024   Prob (F-statistic):           1.47e-42
# Time:                        22:16:30   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
print(model.params)
print(model.conf_int())
print(model.pvalues)
print(model.rsquared)
# Out:
# Intercept                7.032594
# Q("TV Ad Budget ($)")    0.047537
# dtype: float64
#                               0         1
# Intercept              6.129719  7.935468
# Q("TV Ad Budget ($)")  0.042231  0.052843
# Intercept                1.406300e-35
# Q("TV Ad Budget ($)")    1.467390e-42
# dtype: float64
# 0.6118750508500712

# %%
model = smf.ols (formula = 'Q("Sales ($)") ~ Q("TV Ad Budget ($)") + Q("Radio Ad Budget ($)") + Q("Newspaper Ad Budget ($)")' ,data = data). fit()
model. summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         Q("Sales ($)")   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Sun, 14 Jan 2024   Prob (F-statistic):           1.58e-96
# Time:                        22:31:22   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
print(model.params)
print(model.conf_int())
print(model.pvalues)
print(model.rsquared)
# Out:
# Intercept                       2.938889
# Q("TV Ad Budget ($)")           0.045765
# Q("Radio Ad Budget ($)")        0.188530
# Q("Newspaper Ad Budget ($)")   -0.001037
# dtype: float64
#                                      0         1
# Intercept                     2.323762  3.554016
# Q("TV Ad Budget ($)")         0.043014  0.048516
# Q("Radio Ad Budget ($)")      0.171547  0.205513
# Q("Newspaper Ad Budget ($)") -0.012616  0.010541
# Intercept                       1.267295e-17
# Q("TV Ad Budget ($)")           1.509960e-81
# Q("Radio Ad Budget ($)")        1.505339e-54
# Q("Newspaper Ad Budget ($)")    8.599151e-01
# dtype: float64
# 0.8972106381789522

# %%
y = 2
if y == 2: x = 0
else: x = 1
x
# Out:
# 0
