# %%
import pandas as pd;

df = pd.read_csv("./datasets/HousePrices.csv")

df.head(2)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
#
#    yr_renovated                street       city  statezip country
# 0          2005  18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0       709 W Blaine St    Seattle  WA 98119     USA

# %%
len(df)
# Out:
# 4600

# %%
df.set_index(['city', 'date'], inplace=True)
df.index
# Out:
# MultiIndex([(   'Shoreline', '2014-05-02 00:00:00'),
#             (     'Seattle', '2014-05-02 00:00:00'),
#             (        'Kent', '2014-05-02 00:00:00'),
#             (    'Bellevue', '2014-05-02 00:00:00'),
#             (     'Redmond', '2014-05-02 00:00:00'),
#             (     'Seattle', '2014-05-02 00:00:00'),
#             (     'Redmond', '2014-05-02 00:00:00'),
#             ('Maple Valley', '2014-05-02 00:00:00'),
#             (  'North Bend', '2014-05-02 00:00:00'),
#             (     'Seattle', '2014-05-02 00:00:00'),
#             ...
#             (      'Renton', '2014-07-08 00:00:00'),
#             (     'Seattle', '2014-07-08 00:00:00'),
#             ( 'Federal Way', '2014-07-08 00:00:00'),
#             (      'Auburn', '2014-07-08 00:00:00'),
#             (        'Kent', '2014-07-09 00:00:00'),
#             (     'Seattle', '2014-07-09 00:00:00'),
#             (    'Bellevue', '2014-07-09 00:00:00'),
# ...

# %%
df.loc["Seattle"].loc["2014-07-08 00:00:00"]
# Out:
#                             price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-07-08 00:00:00  4.380000e+05       2.0       2.00         1270      1372
# 2014-07-08 00:00:00  3.150000e+05       2.0       1.00         1080      2674
# 2014-07-08 00:00:00  7.800000e+05       2.0       2.50         2560      2500
# 2014-07-08 00:00:00  4.800000e+05       2.0       1.00         1060      3040
# 2014-07-08 00:00:00  3.300000e+05       3.0       2.25         2220      4060
# 2014-07-08 00:00:00  3.265000e+05       3.0       1.00         1060      7920
# 2014-07-08 00:00:00  2.670000e+05       3.0       1.00         1400      8100
# 2014-07-08 00:00:00  3.620000e+05       5.0       3.00         1810      3000
# 2014-07-08 00:00:00  3.715000e+05       3.0       1.00         1650      6400
# 2014-07-08 00:00:00  3.680000e+05       4.0       1.75         2100     11942
# 2014-07-08 00:00:00  4.275500e+05       2.0       1.00          880      4000
# ...

# %%
df.loc["Seattle"].loc[]
